# %% [markdown]
# <a href="https://colab.research.google.com/github/gguliants/FutureMakers2022/blob/main/GG_Day_13_Overfitting_Underfitting_SV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image_2021-10-30_133041.png](data:image/png;base64,...)

# %% [markdown]
# #Day 13 Objectives:
# * To acquaint you with the problem of overfit models and to mitigate it with regularization

# %% [markdown]
# #Overfitting and Underfitting
#
# **Overfitting** occurs when you achieve a good fit of your model on the training data, while it does not generalize well on new, unseen data. In other words, the model learnt patterns specific to the training data, which are irrelevant in other data.
#
# We can identify overfitting by looking at validation metrics, like loss or accuracy. Usually the validation metric stops improving after a certain number of epochs and begins to decrease afterwards. The training metric continues to improve because the model seeks to find the best fit for the training data.
#
# There are several manners in which we can reduce overfitting in deep learning models. The best option is to get more training data. Unfortunately, in real-world situations you often do not have this possibility due to time, budget or technical constraints.
#
# Another way to reduce overfitting is to lower the capacity of the model to memorize the training data. As such, the model will need to focus on the relevant patterns in the training data, which results in better generalization. In this post we'll discuss three options to achieve this.
#
# **Underfitting** is a scenario where a data model is unable to capture the relationship between the input and output variables accurately, generating a high error rate on both the training set and unseen data.

# %%
# Basic packages
import pandas as pd 
import numpy as np
import re
import collections
import matplotlib.pyplot as plt
from pathlib import Path

# Packages for data preparation
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelEncoder

import nltk
nltk.download('stopwords')

# Packages for modeling
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
NB_WORDS = 10000  # Parameter indicating the number of words we'll put in the dictionary
NB_START_EPOCHS = 20  # Number of epochs we usually start to train with
BATCH_SIZE = 512  # Size of the batches used in the mini-batch gradient descent
MAX_LEN = 20  # Maximum number of words in a sequence

# %%
root = Path('../content/')
input_path = root / 'input/' 
ouput_path = root / 'output/'
source_path = root / 'source/'

# %% [markdown]
# Now we have dealt with neural networks enough that we do not need to handle them directly so we shall work with helper functions.

# %% [markdown]
# ## Question 1
#
# You will be dealing with a dataset containing Tweets. You have learned about data cleaning in the past days. How will you "clean" Tweets before trying to learn some patterns from the text?
#
# *Hint*: Check out the helper functions to learn more about data cleaning in language.
#
# ***ANSWER:***
# **Drop NaN's or missing data. Remove punctuation (string.punctuation). Create if statement to drop duplicated values (if there are any) if that applies.**

# %% [markdown]
# #Helper Functions

# %% [markdown]
# ## Compile a model with losses and weights and train it
#
# Function to train a multi-class model. The number of epochs and
# batch_size are set by the constants at the top of the
# notebook.
#
# Parameters:
# * model : model with the chosen architecture
# * X_train : training features
# * y_train : training target
# * X_valid : validation features
# * Y_valid : validation target
#
# Output:
# * model training history

# %%
def deep_model(model, X_train, y_train, X_valid, y_valid):
    model.compile(optimizer='rmsprop'
                  , loss='categorical_crossentropy'
                  , metrics=['accuracy'])
    
    history = model.fit(X_train
                       , y_train
                       , epochs=NB_START_EPOCHS
                       , batch_size=BATCH_SIZE
                       , validation_data=(X_valid, y_valid)
                       , verbose=1)
    return history

# %% [markdown]
# ## Plot the performance of a model over a chosen metric
#
# Function to evaluate a trained model on a chosen metric.
# Training and validation metric are plotted in a
# line chart for each epoch.
#
# Parameters:
# * `history`: model training history
# * `metric_name`: loss or accuracy
#
# Output:
# * line chart with epochs of x-axis and metric on
# y-axis

# %%
def eval_metric(model, history, metric_name):
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]

    e = range(1, NB_START_EPOCHS + 1)

    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    plt.show()

# %% [markdown]
# ## Test a chosen model on its validation set
#
# Function to test the model on new data after training it
# on the full training data with the optimal number of epochs.
#
# Parameters:
#
# * `model`: trained model
#
# * `X_train`: training features
#
# * `y_train`: training target
#
# * `X_test`: test features
#
# * `y_test`: test target
#
# * `epochs`: optimal number of epochs
#
# Output:
#
# * test accuracy and test loss

# %%
def test_model(model, X_train, y_train, X_test, y_test, epoch_stop):
    model.fit(X_train
              , y_train
              , epochs=epoch_stop
              , batch_size=BATCH_SIZE
              , verbose=1)
    results = model.evaluate(X_test, y_test)
    print()
    print('Test accuracy: {0:.2f}%'.format(results[1]*100))
    return results

# %% [markdown]
# ## Remove stopwords from dataset to make the data cleaner
#
# Function to remove English stopwords from a Pandas Series.
#
# Parameters:
# * `input_text`: text to clean
#
# Output:
# * cleaned Pandas Series

# %%
def remove_stopwords(input_text):
    stopwords_list = stopwords.words('english')
    # Some words which might indicate a certain sentiment are kept via a whitelist
    whitelist = ["n't", "not", "no"]
    words = input_text.split() 
    clean_words = [word for word in words if (word not in stopwords_list or word in whitelist) and len(word) > 1] 
    return " ".join(clean_words)

# %% [markdown]
# ## Removing mentions from tweets
#
# Function to remove mentions, preceded by @, in a Pandas Series
#
# Parameters:
# *    `input_text`: text to clean
#
# Output:
# *    cleaned Pandas Series

# %%
def remove_mentions(input_text):
    return re.sub(r'@\w+', '', input_text)

# %% [markdown]
# ## Compare two different models by metrics
#
# Function to compare a metric between two models
#
# Parameters:
#
# * `model_hist_1`: training history of model 1
#
# * `model_hist_2`: training history of model 2
#
# * `metric`: metric to compare, loss, acc, val_loss or val_acc
#
# Output:
# * plot of metrics of both models

# %%
def compare_models_by_metric(model_1, model_2, model_hist_1, model_hist_2, metric):
    metric_model_1 = model_hist_1.history[metric]
    metric_model_2 = model_hist_2.history[metric]

    e = range(1, NB_START_EPOCHS + 1)
    
    metrics_dict = {
        'acc' : 'Training Accuracy',
        'loss' : 'Training Loss',
        'val_acc' : 'Validation accuracy',
        'val_loss' : 'Validation loss'
    }
    
    metric_label = metrics_dict[metric]

    plt.plot(e, metric_model_1, 'bo', label=model_1.name)
    plt.plot(e, metric_model_2, 'b', label=model_2.name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_label)
    plt.title('Comparing ' + metric_label + ' between models')
    plt.legend()
    plt.show()

# %% [markdown]
# ## Calculating the epoch at which the loss is at its minimum
#
# Function to return the epoch number where the validation loss is
# at its minimum
#
# Parameters:
# *        `model_hist`: training history of model
#
# Output:
# * epoch number with minimum validation loss

# %%
def optimal_epoch(model_hist):
    min_epoch = np.argmin(model_hist.history['val_loss']) + 1
    print("Minimum validation loss reached in epoch {}".format(min_epoch))
    return min_epoch

# %% [markdown]
# #Data preparation

# %%
! gdown --id 1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u 
! mkdir input/ 
! mv Tweets.csv input/
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
# To: /content/Tweets.csv
# 100% 3.42M/3.42M [00:00<00:00, 190MB/s]

# %% [markdown]
# ## Data cleaning
# We load the csv with the tweets and perform a random shuffle. It's a good practice to shuffle the data before splitting between a train and test set. That way the sentiment classes are equally distributed over the train and test sets. We'll only keep the text column as input and the airline_sentiment column as the target.
#
# The next thing we will do is removing stopwords. Stopwords do not have any value for predicting the sentiment. Furthermore, as we want to build a model that can be used for other airline companies as well, we remove the mentions.

# %%
df = pd.read_csv(input_path / 'Tweets.csv')
df = df.reindex(np.random.permutation(df.index))  
df = df[['text', 'airline_sentiment']]
df.text = df.text.apply(remove_stopwords).apply(remove_mentions)

# %% [markdown]
# ## Train-Test split
# The evaluation of the model performance needs to be done on a separate test set. As such, we can estimate how well the model generalizes. This is done with the train_test_split method of scikit-learn.

# %%
X_train, X_test, y_train, y_test = train_test_split(df.text, df.airline_sentiment, test_size=0.1, random_state=37)
print('# Train data samples:', X_train.shape[0])
print('# Test data samples:', X_test.shape[0])
assert X_train.shape[0] == y_train.shape[0]
assert X_test.shape[0] == y_test.shape[0]
# Out:
# # Train data samples: 13176
# # Test data samples: 1464

# %% [markdown]
# ## Converting words to numbers
# To use the text as input for a model, we first need to convert the words into tokens, which simply means converting the words to integers that refer to an index in a dictionary. Here we will only keep the most frequent words in the training set.
#
# We clean up the text by applying filters and putting the words to lowercase. Words are separated by spaces.

# %%
tk = Tokenizer(num_words=NB_WORDS,
               filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',
               lower=True,
               char_level=False,
               split=' ')
tk.fit_on_texts(X_train)

print('Fitted tokenizer on {} documents'.format(tk.document_count))
print('{} words in dictionary'.format(tk.num_words))
print('Top 5 most common words are:', collections.Counter(tk.word_counts).most_common(5))
# Out:
# Fitted tokenizer on 13176 documents
# 10000 words in dictionary
# Top 5 most common words are: [('flight', 3533), ('not', 1429), ('no', 1365), ('get', 1224), ('t', 1104)]

# %% [markdown]
# After having created the dictionary we can convert the text of a tweet to a vector with `NB_WORDS` values. With `mode=binary`, it contains an indicator whether the word appeared in the tweet or not. This is done with the texts_to_matrix method of the Tokenizer.

# %%
X_train_oh = tk.texts_to_matrix(X_train, mode='binary')
X_test_oh = tk.texts_to_matrix(X_test, mode='binary')

# %% [markdown]
# ## Converting the target classes to numbers
# We need to convert the target classes to numbers as well, which in turn are one-hot-encoded with the to_categorical method in Keras

# %%
le = LabelEncoder()
y_train_le = le.fit_transform(y_train)
y_test_le = le.transform(y_test)
y_train_oh = to_categorical(y_train_le)
y_test_oh = to_categorical(y_test_le)

print('"{}" is converted into {}'.format(y_train[0], y_train_le[0]))
print('"{}" is converted into {}'.format(y_train_le[0], y_train_oh[0]))
# Out:
# "neutral" is converted into 0
# "0" is converted into [1. 0. 0.]

# %% [markdown]
# ## Splitting off a validation set
# Now that our data is ready, we split off a validation set. This validation set will be used to evaluate the model performance when we tune the parameters of the model.

# %%
X_train_rest, X_valid, y_train_rest, y_valid = train_test_split(X_train_oh, y_train_oh, test_size=0.1, random_state=37)

assert X_valid.shape[0] == y_valid.shape[0]
assert X_train_rest.shape[0] == y_train_rest.shape[0]

print('Shape of validation set:',X_valid.shape)
# Out:
# Shape of validation set: (1318, 10000)

# %% [markdown]
# # Bias and Variance
#
# *Bias* and *variance* are two terms you need to get used to if constructing statistical models, such as those in machine learning. There is a tension between wanting to construct a model which is complex enough to capture the system that we are modelling, but not so complex that we start to fit to noise in the training data. This is related to underfitting and overfitting of a model to data, and back to the bias-variance tradeoff.
#
# If we have an *underfitted* model, this means that we do not have enough parameters to capture the trends in the underlying system. Imagine for example that we have data that is parabolic in nature, but we try to fit this with a linear function, with just one parameter. Because the function does not have the required complexity to fit the data (two parameters), we end up with a poor predictor. In this case the model will have high bias. This means that we will get consistent answers, but consistently wrong answers.
#
# If we have overfitted, this means that we have too many parameters to be justified by the actual underlying data and therefore build an overly complex model. Again imagine that the true system is a parabola, but we used a higher order polynomial to fit to it. Because we have natural noise in the data used to fit (deviations from the perfect parabola), the overly complex model treats these fluctuations and noise as if they were intrinsic properties of the system and attempts to fit to them. The result is a model that has high variance. This means that we will not get consistent predictions of future results.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Creating a model that overfits
# We start with a model that overfits. It has 2 densely connected layers of 64 elements. The input_shape for the first layer is equal to the number of words we kept in the dictionary and for which we created one-hot-encoded features.
#
# As we need to predict 3 different sentiment classes, the last layer has 3 elements. The softmax activation function makes sure the three probabilities sum up to 1.
#
# The number of parameters to train is computed as (nb inputs x nb elements in hidden layer) + nb bias terms. The number of inputs for the first layer equals the number of words in our corpus. The subsequent layers have the number of outputs of the previous layer as inputs. So the number of parameters per layer are:
#
# * First layer : (10000 x 64) + 64 = 640064
# * Second layer : (64 x 64) + 64 = 4160
# * Last layer : (64 x 3) + 3 = 195

# %%
base_model = models.Sequential()
base_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
base_model.add(layers.Dense(64, activation='relu'))
base_model.add(layers.Dense(3, activation='softmax'))
base_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                640064
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Because this project is a multi-class, single-label prediction, we use categorical_crossentropy as the loss function and softmax as the final activation function. We fit the model on the train data and validate on the validation set. We run for a predetermined number of epochs and will see when the model starts to overfit.

# %%
base_history = deep_model(base_model, X_train_rest, y_train_rest, X_valid, y_valid)
base_min = optimal_epoch(base_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 2s 68ms/step - loss: 0.8473 - accuracy: 0.6331 - val_loss: 0.7002 - val_accuracy: 0.6920
# Epoch 2/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.5902 - accuracy: 0.7746 - val_loss: 0.5620 - val_accuracy: 0.7701
# Epoch 3/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.4342 - accuracy: 0.8517 - val_loss: 0.5169 - val_accuracy: 0.7929
# Epoch 4/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.3393 - accuracy: 0.8823 - val_loss: 0.5261 - val_accuracy: 0.7944
# Epoch 5/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.2770 - accuracy: 0.9034 - val_loss: 0.5573 - val_accuracy: 0.7959
# Epoch 6/20
# 24/24 [==============================] - 1s 62ms/step - loss: 0.2304 - accuracy: 0.9183 - val_loss: 0.6022 - val_accuracy: 0.7898
# Epoch 7/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.1919 - accuracy: 0.9328 - val_loss: 0.6417 - val_accuracy: 0.7845
# Epoch 8/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.1607 - accuracy: 0.9449 - val_loss: 0.6898 - val_accuracy: 0.7830
# Epoch 9/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.1353 - accuracy: 0.9560 - val_loss: 0.7451 - val_accuracy: 0.7785
# Epoch 10/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.1150 - accuracy: 0.9630 - val_loss: 0.7842 - val_accuracy: 0.7777
# Epoch 11/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0972 - accuracy: 0.9683 - val_loss: 0.8977 - val_accuracy: 0.7716
# Epoch 12/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0839 - accuracy: 0.9728 - val_loss: 0.9182 - val_accuracy: 0.7716
# Epoch 13/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0722 - accuracy: 0.9776 - val_loss: 0.9974 - val_accuracy: 0.7739
# Epoch 14/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0627 - accuracy: 0.9804 - val_loss: 1.1042 - val_accuracy: 0.7709
# Epoch 15/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0547 - accuracy: 0.9820 - val_loss: 1.1518 - val_accuracy: 0.7678
# Epoch 16/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0478 - accuracy: 0.9850 - val_loss: 1.2038 - val_accuracy: 0.7663
# Epoch 17/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0428 - accuracy: 0.9860 - val_loss: 1.3035 - val_accuracy: 0.7618
# Epoch 18/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0387 - accuracy: 0.9872 - val_loss: 1.3367 - val_accuracy: 0.7656
# Epoch 19/20
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0353 - accuracy: 0.9890 - val_loss: 1.4048 - val_accuracy: 0.7633
# Epoch 20/20
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0314 - accuracy: 0.9897 - val_loss: 1.4533 - val_accuracy: 0.7640
# Minimum validation loss reached in epoch 3

# %%
eval_metric(base_model, base_history, 'loss')

# %% [markdown]
# In the beginning the validation loss goes down. But at epoch 3 this stops and the validation loss starts increasing rapidly. This is when the models begins to overfit.
#
# The training loss continues to go down and almost reaches zero at epoch 20. This is normal as the model is trained to fit the train data as good as possible.

# %% [markdown]
# ## Question 2
#
# Intuitively, what kind of model would have underfitted the Tweets dataset? Define the model architecture below.

# %% [markdown]
# ### Answer 2

# %%
#binary cross entropy
base_model = models.Sequential()
base_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
base_model.add(layers.Dense(64, activation='relu'))
base_model.add(layers.Dense(3, activation='softmax'))
base_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 64)                640064
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dense_5 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Question 3
#
# In case of underfitting, what is the behavior of the training/testing loss vs epoch curve?
#
# ***ANSWER:***
# **The loss function is high and does not decrease with number of epochs. The training loss could also remain flat or continue to decrease as epochs increase.**

# %% [markdown]
# ## Handling overfitting
# Now, we can try to do something about the overfitting. There are different options to do that.
#
# * Option 1: reduce the network's capacity by removing layers or reducing the number of elements in the hidden layers
# * Option 2: apply regularization, which comes down to adding a cost to the loss function for large weights
# * Option 3: use Dropout layers, which will randomly remove certain features by setting them to zero

# %% [markdown]
# ## Question 4
#
# From the regularization methods we have used as of yet, what are the main takeaways on reducing underfitting and reducing overfitting?
#
# ***ANSWER:***
# **It is vital to not use too complicated of a neural network, as it can result in overfitting. Underfitting is not reduced by regularization, but focuses on obtaining low error.**

# %% [markdown]
# ## Reducing the network's capacity
# Our first model has a large number of trainable parameters. The higher this number, the easier the model can memorize the target class for each training sample. Obviously, this is not ideal for generalizing on new data.
#
# By lowering the capacity of the network, you force it to learn the patterns that matter, or that minimize the loss. On the other hand, reducing the network's capacity too much, will lead to underfitting. The model will not be able to learn the relevant patterns in the train data.
#
# We reduce the network's capacity by removing one hidden layer and lowering the number of elements in the remaining layer to 16.

# %%
reduced_model = models.Sequential()
reduced_model.add(layers.Dense(16, activation='relu', input_shape=(NB_WORDS,)))
reduced_model.add(layers.Dense(3, activation='softmax'))
reduced_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 16)                160016
#
#  dense_7 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 160,067
# Trainable params: 160,067
# Non-trainable params: 0
# _________________________________________________________________

# %%
reduced_history = deep_model(reduced_model, X_train_rest, y_train_rest, X_valid, y_valid)
reduced_min = optimal_epoch(reduced_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.9785 - accuracy: 0.6357 - val_loss: 0.8872 - val_accuracy: 0.6669
# Epoch 2/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.8158 - accuracy: 0.6865 - val_loss: 0.7767 - val_accuracy: 0.6904
# Epoch 3/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.7109 - accuracy: 0.7202 - val_loss: 0.7044 - val_accuracy: 0.7071
# Epoch 4/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.6345 - accuracy: 0.7505 - val_loss: 0.6522 - val_accuracy: 0.7307
# Epoch 5/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.5737 - accuracy: 0.7839 - val_loss: 0.6100 - val_accuracy: 0.7489
# Epoch 6/20
# 24/24 [==============================] - 1s 39ms/step - loss: 0.5223 - accuracy: 0.8146 - val_loss: 0.5780 - val_accuracy: 0.7663
# Epoch 7/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.4792 - accuracy: 0.8342 - val_loss: 0.5535 - val_accuracy: 0.7769
# Epoch 8/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.4424 - accuracy: 0.8528 - val_loss: 0.5369 - val_accuracy: 0.7906
# Epoch 9/20
# 24/24 [==============================] - 1s 34ms/step - loss: 0.4112 - accuracy: 0.8654 - val_loss: 0.5254 - val_accuracy: 0.7921
# Epoch 10/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.3845 - accuracy: 0.8748 - val_loss: 0.5175 - val_accuracy: 0.7929
# Epoch 11/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.3610 - accuracy: 0.8827 - val_loss: 0.5125 - val_accuracy: 0.7982
# Epoch 12/20
# 24/24 [==============================] - 1s 39ms/step - loss: 0.3405 - accuracy: 0.8908 - val_loss: 0.5113 - val_accuracy: 0.8005
# Epoch 13/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.3225 - accuracy: 0.8937 - val_loss: 0.5120 - val_accuracy: 0.7989
# Epoch 14/20
# 24/24 [==============================] - 1s 39ms/step - loss: 0.3063 - accuracy: 0.8980 - val_loss: 0.5139 - val_accuracy: 0.7997
# Epoch 15/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.2915 - accuracy: 0.9029 - val_loss: 0.5178 - val_accuracy: 0.7997
# Epoch 16/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.2778 - accuracy: 0.9072 - val_loss: 0.5206 - val_accuracy: 0.7959
# Epoch 17/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.2655 - accuracy: 0.9111 - val_loss: 0.5263 - val_accuracy: 0.7959
# Epoch 18/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.2542 - accuracy: 0.9145 - val_loss: 0.5321 - val_accuracy: 0.7898
# Epoch 19/20
# 24/24 [==============================] - 1s 58ms/step - loss: 0.2435 - accuracy: 0.9176 - val_loss: 0.5393 - val_accuracy: 0.7883
# Epoch 20/20
# 24/24 [==============================] - 1s 63ms/step - loss: 0.2338 - accuracy: 0.9222 - val_loss: 0.5477 - val_accuracy: 0.7853
# Minimum validation loss reached in epoch 12

# %%
eval_metric(reduced_model, reduced_history, 'loss')

# %% [markdown]
# We can see that it takes more epochs before the reduced model starts overfitting. The validation loss also goes up slower than our first model.

# %%
compare_models_by_metric(base_model, reduced_model, base_history, reduced_history, 'val_loss')

# %% [markdown]
# When we compare the validation loss of the baseline model, it is clear that the reduced model starts overfitting at a later epoch. The validation loss stays lower much longer than the baseline model.

# %% [markdown]
# # Applying regularization
#
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# L1 regularization, where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# L2 regularization, where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the squared "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# L1 regularization pushes weights towards exactly zero encouraging a sparse model. L2 regularization will penalize the weights parameters without making them sparse since the penalty goes to zero for small weights-one reason why L2 is more common.
#
# In `tf.keras`, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
reg_model = models.Sequential()
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu', input_shape=(NB_WORDS,)))
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu'))
reg_model.add(layers.Dense(3, activation='softmax'))
reg_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                640064
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  dense_10 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
reg_history = deep_model(reg_model, X_train_rest, y_train_rest, X_valid, y_valid)
reg_min = optimal_epoch(reg_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 5s 155ms/step - loss: 0.9313 - accuracy: 0.6289 - val_loss: 0.7635 - val_accuracy: 0.7162
# Epoch 2/20
# 24/24 [==============================] - 2s 91ms/step - loss: 0.6714 - accuracy: 0.7746 - val_loss: 0.6454 - val_accuracy: 0.7693
# Epoch 3/20
# 24/24 [==============================] - 2s 102ms/step - loss: 0.5490 - accuracy: 0.8381 - val_loss: 0.6067 - val_accuracy: 0.7929
# Epoch 4/20
# 24/24 [==============================] - 2s 102ms/step - loss: 0.4828 - accuracy: 0.8635 - val_loss: 0.6065 - val_accuracy: 0.8012
# Epoch 5/20
# 24/24 [==============================] - 2s 98ms/step - loss: 0.4420 - accuracy: 0.8798 - val_loss: 0.6197 - val_accuracy: 0.7914
# Epoch 6/20
# 24/24 [==============================] - 3s 110ms/step - loss: 0.4124 - accuracy: 0.8894 - val_loss: 0.6330 - val_accuracy: 0.8035
# Epoch 7/20
# 24/24 [==============================] - 3s 108ms/step - loss: 0.3887 - accuracy: 0.8988 - val_loss: 0.6438 - val_accuracy: 0.8005
# Epoch 8/20
# 24/24 [==============================] - 3s 110ms/step - loss: 0.3706 - accuracy: 0.9053 - val_loss: 0.6643 - val_accuracy: 0.7967
# Epoch 9/20
# 24/24 [==============================] - 3s 119ms/step - loss: 0.3516 - accuracy: 0.9168 - val_loss: 0.6759 - val_accuracy: 0.7959
# Epoch 10/20
# 24/24 [==============================] - 1s 59ms/step - loss: 0.3366 - accuracy: 0.9211 - val_loss: 0.6981 - val_accuracy: 0.7936
# Epoch 11/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.3233 - accuracy: 0.9255 - val_loss: 0.6889 - val_accuracy: 0.7838
# Epoch 12/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.3114 - accuracy: 0.9306 - val_loss: 0.7172 - val_accuracy: 0.7777
# Epoch 13/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.3010 - accuracy: 0.9357 - val_loss: 0.7152 - val_accuracy: 0.7891
# Epoch 14/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.2913 - accuracy: 0.9389 - val_loss: 0.7263 - val_accuracy: 0.7830
# Epoch 15/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.2797 - accuracy: 0.9447 - val_loss: 0.7297 - val_accuracy: 0.7883
# Epoch 16/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.2712 - accuracy: 0.9479 - val_loss: 0.7373 - val_accuracy: 0.7944
# Epoch 17/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.2636 - accuracy: 0.9498 - val_loss: 0.7462 - val_accuracy: 0.7876
# Epoch 18/20
# 24/24 [==============================] - 1s 59ms/step - loss: 0.2569 - accuracy: 0.9524 - val_loss: 0.7513 - val_accuracy: 0.7845
# Epoch 19/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.2499 - accuracy: 0.9551 - val_loss: 0.7756 - val_accuracy: 0.7830
# Epoch 20/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.2446 - accuracy: 0.9574 - val_loss: 0.7721 - val_accuracy: 0.7785
# Minimum validation loss reached in epoch 4

# %% [markdown]
# For the regularized model we notice that it starts overfitting in the same epoch as the baseline model. However, the loss increases much slower afterwards.

# %%
eval_metric(reg_model, reg_history, 'loss')

# %%
compare_models_by_metric(base_model, reg_model, base_history, reg_history, 'val_loss')

# %% [markdown]
# ## Question 5
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 5

# %%
from numpy.linalg import norm
weights = [-5, 4, -3, 2, 1]

def l1_norm(weights):
    return norm(weights, 1)

print(l1_norm(weights)) #lasso regression
# Out:
# 15.0

# %% [markdown]
# ## Question 6
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||_2^2$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 6

# %%
weights = [-5, 4, -3, 2, 1]

def l2_norm(weights):
    ans = [(i**2)  for i in weights]
    ans = sum(ans)
    return ans

print(l2_norm(weights))
# Out:
# 55

# %% [markdown]
# ## Adding dropout layers
# Add dropout
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto.
#
# The intuitive explanation for dropout is that because individual nodes in the network cannot rely on the output of the others, each node must output features that are useful on their own.
#
# Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5, 1.3, 0, 1.1].
#
# The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In `tf.keras` you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add two Dropout layers in our network to see how well they do at reducing overfitting:

# %%
drop_model = models.Sequential()
drop_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(64, activation='relu'))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(3, activation='softmax'))
drop_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 64)                640064
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_12 (Dense)            (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_13 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
drop_history = deep_model(drop_model, X_train_rest, y_train_rest, X_valid, y_valid)
drop_min = optimal_epoch(drop_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 2s 62ms/step - loss: 0.8832 - accuracy: 0.6120 - val_loss: 0.7485 - val_accuracy: 0.6252
# Epoch 2/20
# 24/24 [==============================] - 1s 62ms/step - loss: 0.7027 - accuracy: 0.6672 - val_loss: 0.6455 - val_accuracy: 0.7124
# Epoch 3/20
# 24/24 [==============================] - 1s 62ms/step - loss: 0.5976 - accuracy: 0.7662 - val_loss: 0.5705 - val_accuracy: 0.7709
# Epoch 4/20
# 24/24 [==============================] - 1s 62ms/step - loss: 0.5073 - accuracy: 0.8155 - val_loss: 0.5431 - val_accuracy: 0.7822
# Epoch 5/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.4434 - accuracy: 0.8422 - val_loss: 0.5211 - val_accuracy: 0.7951
# Epoch 6/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.3964 - accuracy: 0.8572 - val_loss: 0.5316 - val_accuracy: 0.8012
# Epoch 7/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.3560 - accuracy: 0.8746 - val_loss: 0.5393 - val_accuracy: 0.7982
# Epoch 8/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.3287 - accuracy: 0.8856 - val_loss: 0.5622 - val_accuracy: 0.7997
# Epoch 9/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.2983 - accuracy: 0.8961 - val_loss: 0.5880 - val_accuracy: 0.7974
# Epoch 10/20
# 24/24 [==============================] - 2s 63ms/step - loss: 0.2692 - accuracy: 0.9068 - val_loss: 0.6120 - val_accuracy: 0.7891
# Epoch 11/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.2509 - accuracy: 0.9116 - val_loss: 0.6272 - val_accuracy: 0.7914
# Epoch 12/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.2284 - accuracy: 0.9221 - val_loss: 0.6556 - val_accuracy: 0.7883
# Epoch 13/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.2075 - accuracy: 0.9297 - val_loss: 0.6800 - val_accuracy: 0.7860
# Epoch 14/20
# 24/24 [==============================] - 2s 75ms/step - loss: 0.1973 - accuracy: 0.9327 - val_loss: 0.7089 - val_accuracy: 0.7853
# Epoch 15/20
# 24/24 [==============================] - 2s 102ms/step - loss: 0.1817 - accuracy: 0.9376 - val_loss: 0.7495 - val_accuracy: 0.7891
# Epoch 16/20
# 24/24 [==============================] - 2s 90ms/step - loss: 0.1695 - accuracy: 0.9443 - val_loss: 0.7629 - val_accuracy: 0.7898
# Epoch 17/20
# 24/24 [==============================] - 2s 90ms/step - loss: 0.1550 - accuracy: 0.9484 - val_loss: 0.8086 - val_accuracy: 0.7876
# Epoch 18/20
# 24/24 [==============================] - 3s 110ms/step - loss: 0.1408 - accuracy: 0.9556 - val_loss: 0.8487 - val_accuracy: 0.7822
# Epoch 19/20
# 24/24 [==============================] - 2s 105ms/step - loss: 0.1361 - accuracy: 0.9559 - val_loss: 0.8731 - val_accuracy: 0.7792
# Epoch 20/20
# 24/24 [==============================] - 2s 93ms/step - loss: 0.1245 - accuracy: 0.9573 - val_loss: 0.9263 - val_accuracy: 0.7800
# Minimum validation loss reached in epoch 5

# %%
eval_metric(drop_model, drop_history, 'loss')

# %% [markdown]
# The model with dropout layers starts overfitting later than the baseline model. The loss also increases slower than the baseline model.

# %%
compare_models_by_metric(base_model, drop_model, base_history, drop_history, 'val_loss')

# %% [markdown]
# The model with the Dropout layers starts overfitting later. Compared to the baseline model the loss also remains much lower.

# %% [markdown]
# ## Combined L2 + dropout

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu', input_shape=(NB_WORDS,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(3)
])

# %%
combined_history = deep_model(combined_model, X_train_rest, y_train_rest, X_valid, y_valid)
combined_min = optimal_epoch(combined_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 9s 333ms/step - loss: 1.3968 - accuracy: 0.6068 - val_loss: 1.4978 - val_accuracy: 0.6798
# Epoch 2/20
# 24/24 [==============================] - 8s 334ms/step - loss: 5.0136 - accuracy: 0.3266 - val_loss: 6.6495 - val_accuracy: 0.1510
# Epoch 3/20
# 24/24 [==============================] - 8s 317ms/step - loss: 5.8864 - accuracy: 0.1627 - val_loss: 8.7829 - val_accuracy: 0.1510
# Epoch 4/20
# 24/24 [==============================] - 8s 324ms/step - loss: 9.6339 - accuracy: 0.1679 - val_loss: 10.2269 - val_accuracy: 0.1707
# Epoch 5/20
# 24/24 [==============================] - 8s 328ms/step - loss: 9.0786 - accuracy: 0.1763 - val_loss: 10.2059 - val_accuracy: 0.1980
# Epoch 6/20
# 24/24 [==============================] - 8s 322ms/step - loss: 8.8609 - accuracy: 0.1810 - val_loss: 10.1748 - val_accuracy: 0.1821
# Epoch 7/20
# 24/24 [==============================] - 8s 322ms/step - loss: 7.9397 - accuracy: 0.1734 - val_loss: 5.8842 - val_accuracy: 0.1616
# Epoch 8/20
# 24/24 [==============================] - 8s 347ms/step - loss: 7.2898 - accuracy: 0.1702 - val_loss: 10.1169 - val_accuracy: 0.1965
# Epoch 9/20
# 24/24 [==============================] - 8s 334ms/step - loss: 10.0282 - accuracy: 0.1777 - val_loss: 10.1085 - val_accuracy: 0.1859
# Epoch 10/20
# 24/24 [==============================] - 8s 332ms/step - loss: 9.7446 - accuracy: 0.1786 - val_loss: 10.0988 - val_accuracy: 0.1502
# Epoch 11/20
# 24/24 [==============================] - 8s 346ms/step - loss: 9.4194 - accuracy: 0.1681 - val_loss: 10.0891 - val_accuracy: 0.1510
# Epoch 12/20
# 24/24 [==============================] - 8s 329ms/step - loss: 8.7541 - accuracy: 0.1643 - val_loss: 6.0462 - val_accuracy: 0.1510
# Epoch 13/20
# 24/24 [==============================] - 8s 354ms/step - loss: 6.5194 - accuracy: 0.1666 - val_loss: 6.0426 - val_accuracy: 0.1510
# Epoch 14/20
# 24/24 [==============================] - 9s 361ms/step - loss: 6.4586 - accuracy: 0.1642 - val_loss: 6.0415 - val_accuracy: 0.1510
# Epoch 15/20
# 24/24 [==============================] - 8s 339ms/step - loss: 6.6428 - accuracy: 0.1660 - val_loss: 6.0413 - val_accuracy: 0.1510
# Epoch 16/20
# 24/24 [==============================] - 7s 305ms/step - loss: 6.6468 - accuracy: 0.1650 - val_loss: 6.0412 - val_accuracy: 0.1510
# Epoch 17/20
# 24/24 [==============================] - 8s 333ms/step - loss: 6.8248 - accuracy: 0.1631 - val_loss: 6.0412 - val_accuracy: 0.1510
# Epoch 18/20
# 24/24 [==============================] - 8s 314ms/step - loss: 6.7460 - accuracy: 0.1647 - val_loss: 6.0412 - val_accuracy: 0.1510
# Epoch 19/20
# 24/24 [==============================] - 8s 340ms/step - loss: 6.8058 - accuracy: 0.1625 - val_loss: 6.0412 - val_accuracy: 0.1510
# Epoch 20/20
# 24/24 [==============================] - 8s 330ms/step - loss: 6.8194 - accuracy: 0.1626 - val_loss: 6.0412 - val_accuracy: 0.1510
# Minimum validation loss reached in epoch 1

# %%
eval_metric(combined_model, combined_history, 'loss')

# %%
compare_models_by_metric(base_model, combined_model, base_history, combined_history, 'val_loss')

# %% [markdown]
# ## Question 7
#
# When does it make sense to add both L2 regularization and Dropout?
#
# And what did doing so achieve in this case?
#
# ***ANSWER:***
# **It makes sense to add both when there is overfitting. Dropout helps to avoid memorization of patterns in the model. A good strategy is to lower the loss of the model until overfitting occurs and then adding a dropout layer to reduce the number of parameters.**

# %% [markdown]
# #Training on the full train data and evaluation on test data
# At first sight the reduced model seems to be the best model for generalization. But let's check that on the test set.

# %%
base_model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001), 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
base_results = test_model(base_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, base_min)
# Out:
# Epoch 1/3
# 26/26 [==============================] - 2s 56ms/step - loss: 0.9111 - accuracy: 0.6160
# Epoch 2/3
# 26/26 [==============================] - 1s 52ms/step - loss: 0.6735 - accuracy: 0.6677
# Epoch 3/3
# 26/26 [==============================] - 1s 48ms/step - loss: 0.4849 - accuracy: 0.8238
# 46/46 [==============================] - 1s 4ms/step - loss: 0.4965 - accuracy: 0.8115
#
# Test accuracy: 81.15%

# %%
reduced_results = test_model(reduced_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reduced_min)
# Out:
# Epoch 1/12
# 26/26 [==============================] - 1s 40ms/step - loss: 0.2569 - accuracy: 0.9122
# Epoch 2/12
# 26/26 [==============================] - 1s 33ms/step - loss: 0.2462 - accuracy: 0.9151
# Epoch 3/12
# 26/26 [==============================] - 1s 33ms/step - loss: 0.2367 - accuracy: 0.9188
# Epoch 4/12
# 26/26 [==============================] - 1s 38ms/step - loss: 0.2275 - accuracy: 0.9236
# Epoch 5/12
# 26/26 [==============================] - 1s 35ms/step - loss: 0.2190 - accuracy: 0.9249
# Epoch 6/12
# 26/26 [==============================] - 1s 29ms/step - loss: 0.2111 - accuracy: 0.9282
# Epoch 7/12
# 26/26 [==============================] - 1s 29ms/step - loss: 0.2035 - accuracy: 0.9303
# Epoch 8/12
# 26/26 [==============================] - 1s 35ms/step - loss: 0.1963 - accuracy: 0.9326
# Epoch 9/12
# 26/26 [==============================] - 1s 38ms/step - loss: 0.1896 - accuracy: 0.9359
# Epoch 10/12
# 26/26 [==============================] - 1s 38ms/step - loss: 0.1833 - accuracy: 0.9376
# Epoch 11/12
# 26/26 [==============================] - 1s 38ms/step - loss: 0.1773 - accuracy: 0.9399
# Epoch 12/12
# 26/26 [==============================] - 1s 37ms/step - loss: 0.1715 - accuracy: 0.9421
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5855 - accuracy: 0.7992
#
# Test accuracy: 79.92%

# %%
reg_results = test_model(reg_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reg_min)
# Out:
# Epoch 1/4
# 26/26 [==============================] - 2s 83ms/step - loss: 0.2926 - accuracy: 0.9392
# Epoch 2/4
# 26/26 [==============================] - 3s 109ms/step - loss: 0.2675 - accuracy: 0.9497
# Epoch 3/4
# 26/26 [==============================] - 3s 114ms/step - loss: 0.2560 - accuracy: 0.9507
# Epoch 4/4
# 26/26 [==============================] - 3s 108ms/step - loss: 0.2460 - accuracy: 0.9574
# 46/46 [==============================] - 0s 8ms/step - loss: 0.7226 - accuracy: 0.7937
#
# Test accuracy: 79.37%

# %%
drop_results = test_model(drop_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, drop_min)
# Out:
# Epoch 1/5
# 26/26 [==============================] - 1s 50ms/step - loss: 0.2010 - accuracy: 0.9432
# Epoch 2/5
# 26/26 [==============================] - 2s 60ms/step - loss: 0.1745 - accuracy: 0.9470
# Epoch 3/5
# 26/26 [==============================] - 2s 58ms/step - loss: 0.1707 - accuracy: 0.9495
# Epoch 4/5
# 26/26 [==============================] - 1s 52ms/step - loss: 0.1503 - accuracy: 0.9545
# Epoch 5/5
# 26/26 [==============================] - 2s 58ms/step - loss: 0.1399 - accuracy: 0.9569
# 46/46 [==============================] - 0s 4ms/step - loss: 0.8092 - accuracy: 0.8012
#
# Test accuracy: 80.12%

# %% [markdown]
# # Handling Underfitting
# * In a general situation, the best strategy is to increase the model complexity by either increasing the number of parameters of your deep learning model or the order of your model. Underfitting is due to the model being simpler than needed. It fails to capture the patterns in the data. Increasing the model complexity will lead to improvement in training performance. If we use a large enough model it can even achieve a training error of zero i.e. the model will memorize the data and suffer from over-fitting. The goal is to hit the optimal sweet spot.
# * Try to train the model for more epochs. Ensure that the loss is decreasing gradually over the course of the training. Otherwise, it is highly likely that there is some kind of bug or problem in the training code/logic itself.
# * If you aren’t shuffling the data after every epoch, it can harm the model performance. Ensuring that you are shuffling the data is a good check to perform at this point.

# %% [markdown]
# #Conclusion
# To recap: here are the most common ways to prevent overfitting in neural networks:
#
# * Get more training data.
# * Reduce the capacity of the network.
# * Add weight regularization.
# * Add dropout.
#
# Two important approaches not covered in this guide are:
#
# * data-augmentation
# * batch normalization
#
# Remember that each method can help on its own, but often combining them can be even more effective.
#
# here are the ways to prevent underfitting
#
# * Get more training data.
# * Increase the size or number of parameters in the model.
# * Increase the complexity of the model.
# * Increasing the training time, until cost function is minimised.

# %% [markdown]
# # Bonus content - Visualizing L2 regularization

# %%
import numpy as np
#%matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.core.debugger import set_trace
import warnings
warnings.filterwarnings('ignore')
import itertools

# %%
def plot_contour(f, x1bound, x2bound, resolution, ax):
    x1range = np.linspace(x1bound[0], x1bound[1], resolution)
    x2range = np.linspace(x2bound[0], x2bound[1], resolution)
    xg, yg = np.meshgrid(x1range, x2range)
    zg = np.zeros_like(xg)
    for i,j in itertools.product(range(resolution), range(resolution)):
        zg[i,j] = f([xg[i,j], yg[i,j]])
    ax.contour(xg, yg, zg, 100)
    return ax

# %% [markdown]
# Let's create a toy data:

# %%
N = 20
x = np.random.rand(N) * 10
y = -4*x + 10 + 2*np.random.randn(N)

# %% [markdown]
# visualize the regularized **cost function**

# %%
cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2)
l2_penalty = lambda w: np.dot(w,w)/2
cost_plus_l2 = lambda w: cost(w) + 5*l2_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l2_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L2 reg. $||w||_2^2$')
plot_contour(cost_plus_l2, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L2 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus question: Plot the same for L1 regularization

# %% [markdown]
# ### Answer

# %%
cost = #Enter your code here
l1_penalty = #Enter your code here
cost_plus_l2 = #Enter your code here

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l1_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L1 reg. $||w||_2^2$')
plot_contour(cost_plus_l1, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L1 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus Question 2
# After looking at the visualization to what the L1 and L2 normalizations, how do they help while training?
#
# \<*Type your answer here*\>

# %% [markdown]
# # **Upload this Day 13 Colab Notebook to your Github repository under "Day 13" folder. Also add your *Reflection* on today's learning in README.md**

# %% [markdown]
# Source: https://towardsdatascience.com/handling-overfitting-in-deep-learning-models-c760ee047c6e
